# %%
# Add relevant Jupyter notebook extensions 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Import your classes from the appropriate modules
import sys
import os

# Add the src directory to the system path
sys.path.append(os.path.abspath('../uuv_mission'))  # Adjust the path as necessary

# Now you can import your module


from dynamic import Submarine, Mission, ClosedLoop
from dynamic import PDController  # Make sure this is correctly imported


#sys.path.append(os.path.abspath('../data'))  # Adjust the path as necessary
#from data import mission

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['/opt/miniconda3/lib/python39.zip', '/opt/miniconda3/lib/python3.9', '/opt/miniconda3/lib/python3.9/lib-dynload', '', '/home/sjoh5679/Documents/vs code b1.1/venv/lib/python3.9/site-packages', '/home/sjoh5679/Documents/vs code b1.1/b1-coding-practical-mt24/uuv_mission']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules

sub = Submarine()
# Instantiate your controller (depending on your implementation)
#define controller
controller = PDController(KP=0.15, KD=0.6)


closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv('mission.csv') # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
